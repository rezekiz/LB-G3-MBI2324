# %%
# Import dos módulos necessários
import Bio.Blast
from Bio.Blast import NCBIWWW 
from Bio.Blast import NCBIXML 
from Bio import SeqIO

# %%
def blast_remoto(arquivo_entrada = '/Users/carla/Downloads/HLA_DQB1.fasta', formato = 'fasta', banco_dados = 'nr', tipo_blast = 'blastp'):

    '''
    Função para a realização do Blast Remoto

    Parâmetros:
    arquivo_entrada : str
        Caminho para o arquivo de entrada contendo a sequência que será usada como consulta

    formato : str
        Formato do arquivo de entrada
    
    banco_dados : str
        Banco de dados usado para a busca BLAST ('nr' para banco de dados não redundante do NCBI)
    
    tipo_blast : str
        Tipo de busca BLAST ('blastp' para proteínas)
    
    
    Retorna:
    resultado : handle
        Objeto que contém os resultados do BLAST
    '''

    # Lê a sequência do arquivo
    record = SeqIO.read(open(arquivo_entrada), format = formato)

    # Executa o Blast Remoto
    resultado = NCBIWWW.qblast(tipo_blast, banco_dados, record.format(formato))

    return resultado


# Guardar Blast
def save_blast(resultado, nome_arquivo = 'blast.xml'):

    '''
    Função para salvar os resultados do BLAST num arquivo XML

    Parâmetros:
    resultado : handle
        Objeto que contém os resultados do BLAST
    
    nome_arquivo : str
        Nome do arquivo onde os resultados vão ser guardados 
    
    O 'with' fecha automaticamente o arquivo 
    '''
    
    with open(nome_arquivo,'w') as save_file:
        save_file.write(resultado.read())

# %%
def resultado_blast(nome_arquivo='blast.xml'):
    '''
    Função para ler e processar os resultados do BLAST armazenados num arquivo XML

    Parâmetros:
    nome_arquivo : str
        Nome do arquivo XML que contêm os resultados do BLAST 

    Retorna:
    blast_record
        Objeto que representa os resultados do BLAST
    
    Raises:
    FileNotFoundError:
        Se o arquivo especificado pelo 'nome_arquivo' não for encontrado

    IOError:
        Se ocorrer um erro durante a leitura do arquivo.
    '''
    
    try:
        # Abre o arquivo XML com os resultados do BLAST
        with open(nome_arquivo) as resultado:
            # Lê o conteúdo do arquivo e retorna o Blast record
            blast_record = NCBIXML.read(resultado)
    except FileNotFoundError as e:
        # Captura e relança a exceção para fornecer uma mensagem de erro mais informativa
        raise FileNotFoundError(f'O arquivo {nome_arquivo} não foi encontrado.') from e
    except IOError as e:
        # Captura e relança a exceção para fornecer uma mensagem de erro mais informativa
        raise IOError(f'Erro ao ler ou processar o arquivo {nome_arquivo}.') from e
    
    return blast_record

def parametros(blast_record):
    
    '''
    Imprime os parâmetros do BLAST

    Parâmetros:
    blast_record 
        Objeto que representa os resultados do BLAST

    Prints:
    Database - str
        Nome do banco de dados utilizado no BLAST
    
    Matrix - str
        Nome da matriz de substituição utilizada
    
    Gap penalties - tuple
        Tuple contendo os gap penalties
    
    '''
    print('PARAMETROS:')
    print('Database - ', blast_record.database)
    print('Matrix - ', blast_record.matrix)
    print('Gap penalties - ', blast_record.gap_penalties)

# Chamar as funções
resultado_blast = resultado_blast()
parametros(resultado_blast)
# Out:
# PARAMETROS:
# Database -  nr
# Matrix -  BLOSUM62
# Gap penalties -  (11, 1)

# %%
def numero_de_hits(blast_record):
    
    '''
    Imprime o número de hits no resultado do BLAST

    Parâmetros:
    blast_record 
        Objeto que representa os resultados do Blast

    Prints:
    Número de Hits - int
        Número total de alinhamentos encontrados durante a busca BLAST.
    '''

    print('Número de Hits: ', len(blast_record.alignments))



def primeiro_alinhamento(blast_record):
    
    '''
    Imprime informações sobre o primeiro alinhamento do resultado do BLAST.

    Parâmetros:
    blast_record 
        Objeto que representa os resultados do BLAST

    Prints:
    Primeiro Alinhamento:
    
    Acession - str
        Número de acesso associado
    
    Hit Id - str
        Identificador único associado 
    
    Definição - str
        Definição 
    
    Length - int
        Comprimento 
    
    HSPs - int
        Número de High Scoring Pairs (HSPs)
    
    E-value - float
        Valor de E associado ao primeiro HSP
    
    Score - float
        Pontuação do primeiro HSP
    
    Length - int
        Comprimento do alinhamento do primeiro HSP
    '''
    
    
    # Obtém o primeiro alinhamento do BLAST
    first_alignment = blast_record.alignments[0]

    # Imprime informações sobre o primeiro alinhamento
    print('Primeiro Alinhamento:')
    print('Acession: ', first_alignment.accession)
    print('Hit Id: ', first_alignment.hit_id)
    print('Definição: ', first_alignment.hit_def)
    print('Length: ', first_alignment.length)
    print('HSPs: ', len(first_alignment.hsps))

    # Obtém o primeiro HSP (High Scoring Pair) do primeiro alinhamento
    first_hsp = first_alignment.hsps[0]

    # Imprime informações sobre o primeiro HSP
    print('E-value: ', first_hsp.expect)
    print('Score: ', first_hsp.score)
    print('Length: ', first_hsp.align_length)

# Chamar as funções
numero_de_hits(resultado_blast)
primeiro_alinhamento(resultado_blast)
# Out:
# Número de Hits:  50
# Primeiro Alinhamento:
# Acession:  P01920
# Hit Id:  sp|P01920.2|
# Definição:  RecName: Full=HLA class II histocompatibility antigen, DQ beta 1 chain; AltName: Full=MHC class II antigen DQB1; Flags: Precursor [Homo sapiens] >gb|AAU87973.1| MHC class II antigen [Homo sapiens] >gb|AAU87977.1| MHC class II antigen [Homo sapiens] >gb|AAU87986.1| MHC class II antigen [Homo sapiens] >gb|AAU88017.1| MHC class II antigen [Homo sapiens] >gb|AAU88027.1| MHC class II antigen [Homo sapiens]
# Length:  261
# HSPs:  1
# E-value:  2.11792e-167
# Score:  1214.0
# Length:  224

# %%
def alinhamentos(blast_record, num_alinhamentos=5):
    '''
    Imprime informações sobre os alinhamentos no resultado da busca BLAST.

    Parâmetros:
    blast_record 
        Objeto que representa os resultados do BLAST

    num_alinhamentos : int
        Número máximo de alinhamentos

    Prints:
    Informações sobre os alinhamentos:
            Sequence: str
                Título
            Accession: str
                Número de acesso
            Definition: str
                Definição
            E-Value: float
                Valor de E associado 
    '''
    for i in range(min(num_alinhamentos, len(blast_record.alignments))):
        alignment = blast_record.alignments[i]
        print(f'Alinhamento {i + 1}:')
        print('Sequence: ', alignment.title)
        print('Accession: ', alignment.accession)
        print('Definition: ', alignment.hit_def)
        for hsp in alignment.hsps:
            print('E-Value: ', hsp.expect)
        print('\n')

# Chama as funções
alinhamentos(resultado_blast, num_alinhamentos=50)
# Out:
# Alinhamento 1:
# Sequence:  sp|P01920.2| RecName: Full=HLA class II histocompatibility antigen, DQ beta 1 chain; AltName: Full=MHC class II antigen DQB1; Flags: Precursor [Homo sapiens] >gb|AAU87973.1| MHC class II antigen [Homo sapiens] >gb|AAU87977.1| MHC class II antigen [Homo sapiens] >gb|AAU87986.1| MHC class II antigen [Homo sapiens] >gb|AAU88017.1| MHC class II antigen [Homo sapiens] >gb|AAU88027.1| MHC class II antigen [Homo sapiens]
# Accession:  P01920
# Definition:  RecName: Full=HLA class II histocompatibility antigen, DQ beta 1 chain; AltName: Full=MHC class II antigen DQB1; Flags: Precursor [Homo sapiens] >gb|AAU87973.1| MHC class II antigen [Homo sapiens] >gb|AAU87977.1| MHC class II antigen [Homo sapiens] >gb|AAU87986.1| MHC class II antigen [Homo sapiens] >gb|AAU88017.1| MHC class II antigen [Homo sapiens] >gb|AAU88027.1| MHC class II antigen [Homo sapiens]
# E-Value:  2.11792e-167
#
#
# Alinhamento 2:
# Sequence:  gb|WEC89288.1| MHC class II antigen [Homo sapiens]
# Accession:  WEC89288
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  2.60874e-167
#
#
# Alinhamento 3:
# Sequence:  gb|AAB41231.1| MHC class II HLA-DQ, partial [Homo sapiens]
# Accession:  AAB41231
# Definition:  MHC class II HLA-DQ, partial [Homo sapiens]
# E-Value:  2.96545e-167
#
#
# Alinhamento 4:
# Sequence:  gb|QFR39818.1| MHC class II antigen [Homo sapiens]
# Accession:  QFR39818
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  3.35743e-167
#
#
# Alinhamento 5:
# Sequence:  emb|CAI2365380.1| MHC class II antigen [Homo sapiens]
# Accession:  CAI2365380
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  3.78803e-167
#
#
# Alinhamento 6:
# Sequence:  gb|QFQ66443.1| MHC class II antigen, partial [Homo sapiens] >gb|UHL61902.1| MHC class II antigen, partial [Homo sapiens] >gb|UTH39009.1| MHC class II antigen, partial [Homo sapiens] >gb|UTK45768.1| MHC class II antigen, partial [Homo sapiens] >gb|UZZ63589.1| HLA-DQB1, partial [Homo sapiens]
# Accession:  QFQ66443
# Definition:  MHC class II antigen, partial [Homo sapiens] >gb|UHL61902.1| MHC class II antigen, partial [Homo sapiens] >gb|UTH39009.1| MHC class II antigen, partial [Homo sapiens] >gb|UTK45768.1| MHC class II antigen, partial [Homo sapiens] >gb|UZZ63589.1| HLA-DQB1, partial [Homo sapiens]
# E-Value:  3.9635e-167
#
#
# Alinhamento 7:
# Sequence:  emb|CAB0472713.1| MHC class II antigen [Homo sapiens] >emb|CAB0472785.1| MHC class II antigen [Homo sapiens]
# Accession:  CAB0472713
# Definition:  MHC class II antigen [Homo sapiens] >emb|CAB0472785.1| MHC class II antigen [Homo sapiens]
# E-Value:  4.36866e-167
#
#
# Alinhamento 8:
# Sequence:  gb|WGZ73950.1| MHC class II antigen [Homo sapiens]
# Accession:  WGZ73950
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  4.92896e-167
#
#
# Alinhamento 9:
# Sequence:  gb|AAC41964.1| MHC class II HLA-DQ-beta-1, partial [Homo sapiens]
# Accession:  AAC41964
# Definition:  MHC class II HLA-DQ-beta-1, partial [Homo sapiens]
# E-Value:  5.36625e-167
#
#
# Alinhamento 10:
# Sequence:  emb|CAB0472747.1| MHC class II antigen [Homo sapiens] >emb|CAB0472790.1| MHC class II antigen [Homo sapiens]
# Accession:  CAB0472747
# Definition:  MHC class II antigen [Homo sapiens] >emb|CAB0472790.1| MHC class II antigen [Homo sapiens]
# E-Value:  6.55578e-167
#
#
# Alinhamento 11:
# Sequence:  gb|ASK05527.1| MHC class II antigen [Homo sapiens]
# Accession:  ASK05527
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  6.55578e-167
#
#
# Alinhamento 12:
# Sequence:  emb|CAC8953468.1| MHC class II antigen [Homo sapiens]
# Accession:  CAC8953468
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  6.55578e-167
#
#
# Alinhamento 13:
# Sequence:  gb|QHR76951.1| MHC class II antigen [Homo sapiens]
# Accession:  QHR76951
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  7.07903e-167
#
#
# Alinhamento 14:
# Sequence:  emb|CUX91059.1| MHC class II antigen [Homo sapiens]
# Accession:  CUX91059
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  8.07502e-167
#
#
# Alinhamento 15:
# Sequence:  emb|CAB0472764.1| MHC class II antigen [Homo sapiens] >emb|CAB0472787.1| MHC class II antigen [Homo sapiens]
# Accession:  CAB0472764
# Definition:  MHC class II antigen [Homo sapiens] >emb|CAB0472787.1| MHC class II antigen [Homo sapiens]
# E-Value:  1.0167e-166
#
#
# Alinhamento 16:
# Sequence:  emb|CAG8857682.1| MHC class II antigen [Homo sapiens] >emb|CAG8857683.1| MHC class II antigen [Homo sapiens]
# Accession:  CAG8857682
# Definition:  MHC class II antigen [Homo sapiens] >emb|CAG8857683.1| MHC class II antigen [Homo sapiens]
# E-Value:  1.22513e-166
#
#
# Alinhamento 17:
# Sequence:  emb|CAB0472725.1| MHC class II antigen [Homo sapiens] >emb|CAB0472752.1| MHC class II antigen [Homo sapiens]
# Accession:  CAB0472725
# Definition:  MHC class II antigen [Homo sapiens] >emb|CAB0472752.1| MHC class II antigen [Homo sapiens]
# E-Value:  1.36718e-166
#
#
# Alinhamento 18:
# Sequence:  emb|CAI2365776.1| MHC class II antigen [Homo sapiens]
# Accession:  CAI2365776
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  1.38226e-166
#
#
# Alinhamento 19:
# Sequence:  gb|AGW82916.2| MHC class II antigen [Homo sapiens]
# Accession:  AGW82916
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  1.3975e-166
#
#
# Alinhamento 20:
# Sequence:  gb|WNI41388.1| MHC class II antigen DQ beta chain [Homo sapiens] >emb|SBO45790.1| MHC class II antigen [Homo sapiens]
# Accession:  WNI41388
# Definition:  MHC class II antigen DQ beta chain [Homo sapiens] >emb|SBO45790.1| MHC class II antigen [Homo sapiens]
# E-Value:  1.4285e-166
#
#
# Alinhamento 21:
# Sequence:  gb|QKW90136.1| MHC class II antigen [Homo sapiens]
# Accession:  QKW90136
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  1.4285e-166
#
#
# Alinhamento 22:
# Sequence:  emb|CUX91083.1| MHC class II antigen [Homo sapiens]
# Accession:  CUX91083
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  1.49258e-166
#
#
# Alinhamento 23:
# Sequence:  emb|CUX91107.1| MHC class II antigen [Homo sapiens]
# Accession:  CUX91107
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  1.50904e-166
#
#
# Alinhamento 24:
# Sequence:  dbj|BCN36386.1| MHC class II antigen, partial [Homo sapiens]
# Accession:  BCN36386
# Definition:  MHC class II antigen, partial [Homo sapiens]
# E-Value:  1.56245e-166
#
#
# Alinhamento 25:
# Sequence:  emb|CAI2365331.1| MHC class II antigen [Homo sapiens]
# Accession:  CAI2365331
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  1.57673e-166
#
#
# Alinhamento 26:
# Sequence:  gb|QKE46673.1| MHC class II antigen [Homo sapiens] >emb|CAB0472750.1| MHC class II antigen [Homo sapiens]
# Accession:  QKE46673
# Definition:  MHC class II antigen [Homo sapiens] >emb|CAB0472750.1| MHC class II antigen [Homo sapiens]
# E-Value:  1.61171e-166
#
#
# Alinhamento 27:
# Sequence:  gb|WEC89287.1| MHC class II antigen [Homo sapiens]
# Accession:  WEC89287
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  1.66563e-166
#
#
# Alinhamento 28:
# Sequence:  emb|CUX91092.1| MHC class II antigen [Homo sapiens]
# Accession:  CUX91092
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  2.02924e-166
#
#
# Alinhamento 29:
# Sequence:  gb|UHJ79826.1| MHC class II antigen, partial [Homo sapiens]
# Accession:  UHJ79826
# Definition:  MHC class II antigen, partial [Homo sapiens]
# E-Value:  2.03323e-166
#
#
# Alinhamento 30:
# Sequence:  gb|QXH29501.1| MHC class II antigen, partial [Homo sapiens]
# Accession:  QXH29501
# Definition:  MHC class II antigen, partial [Homo sapiens]
# E-Value:  2.03323e-166
#
#
# Alinhamento 31:
# Sequence:  gb|AGW82923.2| MHC class II antigen [Homo sapiens]
# Accession:  AGW82923
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  2.05162e-166
#
#
# Alinhamento 32:
# Sequence:  gb|WKE34848.1| MHC class II DQ beta chain [Homo sapiens]
# Accession:  WKE34848
# Definition:  MHC class II DQ beta chain [Homo sapiens]
# E-Value:  2.21537e-166
#
#
# Alinhamento 33:
# Sequence:  gb|URW63632.1| MHC class II antigen [Homo sapiens]
# Accession:  URW63632
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  2.36609e-166
#
#
# Alinhamento 34:
# Sequence:  gb|ATY52316.1| MHC class II antigen [Homo sapiens] >gb|QJX19969.1| MHC class II antigen [Homo sapiens] >emb|CAB0472821.1| MHC class II antigen [Homo sapiens] >emb|CUX91066.1| MHC class II antigen [Homo sapiens]
# Accession:  ATY52316
# Definition:  MHC class II antigen [Homo sapiens] >gb|QJX19969.1| MHC class II antigen [Homo sapiens] >emb|CAB0472821.1| MHC class II antigen [Homo sapiens] >emb|CUX91066.1| MHC class II antigen [Homo sapiens]
# E-Value:  2.36609e-166
#
#
# Alinhamento 35:
# Sequence:  emb|CUX91145.1| MHC class II antigen [Homo sapiens] >emb|CUX91170.1| MHC class II antigen [Homo sapiens]
# Accession:  CUX91145
# Definition:  MHC class II antigen [Homo sapiens] >emb|CUX91170.1| MHC class II antigen [Homo sapiens]
# E-Value:  2.4995e-166
#
#
# Alinhamento 36:
# Sequence:  gb|URH08509.1| MHC class II antigen [Homo sapiens] >emb|CUX91064.1| MHC class II antigen [Homo sapiens] >emb|CUX91072.1| MHC class II antigen [Homo sapiens]
# Accession:  URH08509
# Definition:  MHC class II antigen [Homo sapiens] >emb|CUX91064.1| MHC class II antigen [Homo sapiens] >emb|CUX91072.1| MHC class II antigen [Homo sapiens]
# E-Value:  2.55494e-166
#
#
# Alinhamento 37:
# Sequence:  gb|AGW82924.2| MHC class II antigen [Homo sapiens]
# Accession:  AGW82924
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  2.72876e-166
#
#
# Alinhamento 38:
# Sequence:  gb|QIX12208.1| MHC class II antigen [Homo sapiens]
# Accession:  QIX12208
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  2.85116e-166
#
#
# Alinhamento 39:
# Sequence:  gb|QYV98458.1| MHC class II antigen [Homo sapiens]
# Accession:  QYV98458
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  3.01192e-166
#
#
# Alinhamento 40:
# Sequence:  gb|WCC59860.1| MHC class II antigen [Homo sapiens]
# Accession:  WCC59860
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  3.25231e-166
#
#
# Alinhamento 41:
# Sequence:  gb|QXH29428.1| MHC class II antigen [Homo sapiens]
# Accession:  QXH29428
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  3.25231e-166
#
#
# Alinhamento 42:
# Sequence:  gb|AGW82926.2| MHC class II antigen [Homo sapiens]
# Accession:  AGW82926
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  3.32445e-166
#
#
# Alinhamento 43:
# Sequence:  emb|CAG8857732.1| MHC class II antigen [Homo sapiens] >emb|CAI2365518.1| MHC class II antigen [Homo sapiens] >emb|CAI2365690.1| MHC class II antigen [Homo sapiens]
# Accession:  CAG8857732
# Definition:  MHC class II antigen [Homo sapiens] >emb|CAI2365518.1| MHC class II antigen [Homo sapiens] >emb|CAI2365690.1| MHC class II antigen [Homo sapiens]
# E-Value:  3.96229e-166
#
#
# Alinhamento 44:
# Sequence:  gb|AXU93758.1| MHC class II histocompatibility antigen [Homo sapiens]
# Accession:  AXU93758
# Definition:  MHC class II histocompatibility antigen [Homo sapiens]
# E-Value:  3.96229e-166
#
#
# Alinhamento 45:
# Sequence:  gb|USU81754.1| MHC class II antigen [Homo sapiens] >gb|WBV79789.1| MHC class II antigen [Homo sapiens]
# Accession:  USU81754
# Definition:  MHC class II antigen [Homo sapiens] >gb|WBV79789.1| MHC class II antigen [Homo sapiens]
# E-Value:  4.00599e-166
#
#
# Alinhamento 46:
# Sequence:  gb|QHD25590.1| MHC class I antigen [Homo sapiens]
# Accession:  QHD25590
# Definition:  MHC class I antigen [Homo sapiens]
# E-Value:  4.27853e-166
#
#
# Alinhamento 47:
# Sequence:  gb|AAA36269.1| MHC HLA-DQ-beta cell surface glycoprotein [Homo sapiens]
# Accession:  AAA36269
# Definition:  MHC HLA-DQ-beta cell surface glycoprotein [Homo sapiens]
# E-Value:  5.62856e-166
#
#
# Alinhamento 48:
# Sequence:  emb|CUX91093.1| MHC class II antigen [Homo sapiens]
# Accession:  CUX91093
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  6.85726e-166
#
#
# Alinhamento 49:
# Sequence:  gb|QPI70864.1| MHC class II antigen [Homo sapiens]
# Accession:  QPI70864
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  9.12047e-166
#
#
# Alinhamento 50:
# Sequence:  emb|CAI2365309.1| MHC class II antigen [Homo sapiens]
# Accession:  CAI2365309
# Definition:  MHC class II antigen [Homo sapiens]
# E-Value:  9.12047e-166
